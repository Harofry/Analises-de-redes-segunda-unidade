# %% [markdown]
# # Network Analysis with NetworkX

# %% [markdown]
# In this series of lessons, we're going to learn about network analysis. Network analysis will help us better understand the complex relationships between groups of people, fictional characters, and other kinds of things.

# %% [markdown]
# ## Dataset

# %% [markdown]
# [link text](https://)### *Game of Thrones* modification test

# %% [markdown]
# <blockquote class="epigraph" style=" padding: 10px">
#
# Lucky it might be, and red it certainly was, but Ygritte’s hair was such a tangle that Jon was tempted to ask her if she only brushed it at the changing of the seasons.
#
# -George R. R. Martin, *A Song of Ice and Fire*
# </blockquote>

# %% [markdown]
# ## Network Basics

# %% [markdown]
# ## Install NetworkX

# %%
# !pip install networkx
# Out:
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (3.3)

# %% [markdown]
# ## Import Libraries

# %%
import networkx
import pandas as pd
#pd.set_option('max_rows', 400)
import matplotlib.pyplot as plt

# %% [markdown]
# ## *Game of Thrones* Network

# %% [markdown]
# The network data that we're going to use in this lesson is taken from Andrew Beveridge and Jie Shan's paper, ["Network of Thrones."](https://www.maa.org/sites/default/files/pdf/Mathhorizons/NetworkofThrones%20%281%29.pdf)
#
# These researchers calculated how many times each Game of Thrones character appeared within 15 words of another character in *A Storm of Swords*, the third book in the series.
#
# | Network Element      | GOT |
# | :-------------: |:-------------:|
# | Node    | GOT character |
# | Edge     | Mutually mentioned within 15 words      |
# | Float | Decimal Numbers      |
# | Boolean | True/False     |
#
#
# For example, the following sentence counts as an "edge" or connection between Jon Snow and Sam Tarly:

# %% [markdown]
# > "It was the bastard **Jon Snow** who had taken that from him, him and his fat friend **Sam Tarly**."

# %% [markdown]
# > "Lucky it might be, and red it certainly was, but **Ygritte**’s hair was such a tangle that **Jon** was tempted to ask her if she only brushed it at the changing of the seasons."

# %% [markdown]
# > "**Arya** gave **Gendry** a sideways look. *He said it with me, like **Jon** used to do, back in Winterfell.* She missed **Jon Snow** the most of all her brothers.""

# %% [markdown]
# :::{admonition} Pandas Review
# :class: pandasreview
#  Do you need a refresher or introduction to the Python data analysis library Pandas? Be sure to check out <a href="https://melaniewalsh.github.io/Intro-Cultural-Analytics/Data-Analysis/Pandas-Basics-Part1.html"> Pandas Basics (1-3) </a> in this textbook!
# :::

# %%
# Try reading the file with a different encoding, like 'latin-1'
got_df = pd.read_csv('https://raw.githubusercontent.com/Harofry/Analises-de-redes-segunda-unidade/main/Just%20a%20testing%20csv%20repo%20-%20Vietnam%20War/THOR_Vietnam_Aircraft_Glossary.csv', encoding='latin-1')

# If you're unsure of the correct encoding, try 'ISO-8859-1' or 'cp1252'
# got_df = pd.read_csv('your_file.csv', encoding='ISO-8859-1')
# got_df = pd.read_csv('your_file.csv', encoding='cp1252')

# You can also try to automatically detect the encoding using the 'chardet' library
# !pip install chardet
import chardet
import requests # Import requests to fetch data from URL

# Fetch the content from the URL
url = 'https://raw.githubusercontent.com/Harofry/Analises-de-redes-segunda-unidade/main/Just%20a%20testing%20csv%20repo%20-%20Vietnam%20War/THOR_Vietnam_Aircraft_Glossary.csv'
response = requests.get(url)

# Detect the encoding
result = chardet.detect(response.content)

# Read the file with the detected encoding
got_df = pd.read_csv(url, encoding=result['encoding'])

got_df = pd.read_csv('https://raw.githubusercontent.com/Harofry/Analises-de-redes-segunda-unidade/main/Just%20a%20testing%20csv%20repo%20-%20Vietnam%20War/THOR_Vietnam_Weapons_Glossary.csv', encoding=result['encoding'])
# Out:
# Requirement already satisfied: chardet in /usr/local/lib/python3.10/dist-packages (5.2.0)

# %%
got_df
# Out:
#      WEAPON_ID             WEAPONTYPE        WEAPONTYPE_COMMON_NAME  \
# 0            1                 100 GP          General Purpose Bomb
# 1            2                 1000 G  Megaboller flash powder bomb
# 2            3         1000LB GP M-65                        An-M65
# 3            4           1000LB MK-83                  Mark 83 bomb
# 4            5         1000LB SAP M59                        AN-M59
# ..         ...                    ...                           ...
# 289        290        XM384 40MM AMMO                           NaN
# 290        291                 XM40E5            XM40E5 Gravel Bomb
# 291        292          XM41UNITS-CAN                           NaN
# 292        293  XM42 (XM12) GRVL BOMB                           NaN
# 293        294  XM54 MICROGRAVEL BOMB                           NaN
#
#     WEAPON_CLASS                                    WEAPONTYPE_DESC  \
# 0           BOMB                             100 lb general purpose
# 1           BOMB                                         1000 g BKS
# 2           BOMB                           1000 lb general purpose
# 3           BOMB         1000 lb none guidence general purpose bomb
# 4           BOMB                   1000 lb semi-armor piercing bomb
# ..           ...                                                ...
# 289      SUPPORT                                                NaN
# 290      MISSILE  0.54 g of Chlorate/Phosphorus based explosive ...
# 291      MISSILE                                                NaN
# 292      MISSILE                                                NaN
# 293      MISSILE                                                NaN
#
#      WEAPON_COUNT
# 0               1
# 1               2
# 2           12776
# 3           15522
# 4             454
# ..            ...
# 289           477
# 290             3
# 291            14
# 292             2
# 293             1
#
# [294 rows x 6 columns]

# %% [markdown]
# ## Create a Network From a Pandas DataFrame

# %%
G = networkx.from_pandas_edgelist(got_df, 'WEAPONTYPE_COMMON_NAME', 'WEAPON_CLASS', 'WEAPON_COUNT') # Removed the extra tab from 'WEAPON_CLASS'

# %% [markdown]
# ## Output a Network File

# %%
networkx.write_graphml(G, 'GOT-network.graphml')

# %% [markdown]
# ## Draw a Simple Network

# %%
networkx.draw(G)

# %%
plt.figure(figsize=(8,8))
networkx.draw(G, with_labels=True, node_color='skyblue', width=.3, font_size=8)

# %% [markdown]
# ## Calculate Degree

# %% [markdown]
# Who has the most number of connections in the network?

# %%
networkx.degree(G)
# Out:
# DegreeView({'General Purpose Bomb': 1, 'BOMB': 77, 'Megaboller flash powder bomb': 1, 'An-M65': 1, 'Mark 83 bomb': 1, 'AN-M59': 1, nan: 5, 'AN-M30': 1, 'M47': 1, 'Howitzer ammo': 1, 'GUN': 2, 'Hydra 70': 1, 'ROCKET': 10, 'AN-M66': 1, 'Mk-84': 1, 'BLU-10/B': 1, 'AN-M57': 1, 'Mk 81': 1, 'SUPPORT': 11, 'BLU-34/B': 1, 'M-118': 1, 'BLU-11/B': 1, 'AN-M64': 1, 'Mk 82': 1, 'M-117': 1, 'BLU-1/B': 1, 'ADU-253/B': 2, 'ADU-272/B': 1, 'ADU-285/B': 1, 'AGM-12 Bullpup': 1, 'MISSILE': 13, 'AGM-45 Shrike': 1, 'AGM-62ÊWalleye': 2, 'AGM-62ÊWalleye I': 1, 'AGM-62A WALLEYE II': 1, 'AGM-65 Maverick': 1, 'AIM-26B Falcon': 1, 'AIM-4 Falcon': 1, 'AIM-7 Sparrow': 1, 'AIM-9 Sidewinder': 1, 'BLU-23/B': 1, 'BLU-26/B': 1, 'BLU-27/B': 1, 'BLU-31/B': 1, 'BLU-32/B': 1, 'BLU-33/B': 1, 'BLU-42/B': 1, 'BLU-43/B': 1, 'BLU-52/B': 1, 'BLU-73/B': 1, 'BLU-82/B': 1, 'CBU-30/A': 1, 'CBU-42/A': 1, 'CBU-46/A': 1, 'CBU-1/A': 1, 'CBU-10/B': 1, 'CBU-11/A': 1, 'CBU-12/A': 1, 'CBU-14/A': 1, 'CBU-15/A': 1, 'CBU-18/A': 1, 'CBU-19/A': 1, 'CBU-2/A': 1, 'CBU-22/A': 1, 'CBU-23/B': 1, 'CBU-24/B': 1, 'CBU-25/A': 1, 'CBU-28/A': 1, 'CBU-29/B': 1, 'CBU-3/A': 1, 'CBU-33/A': 1, 'CBU-34/A': 1, 'CBU-38/A': 1, 'CBU-39/A': 1, 'CBU-40/A': 1, 'CBU-49/B': 1, 'CBU-52/B': 1, 'CBU-55/B': 1, 'CBU-58/B': 1, 'CBU-7/A': 1, 'AIM-26 Falcon': 1, 'BOLT-117': 1, 'LAU-10/A': 1, 'LAU-3/A': 1, 'LAU-32/A': 1, 'LAU-33/A': 1, 'LAU-56/A': 1, 'LAU-59/A': 1, 'LAU-68/A': 1, 'M104 Bomb': 1, 'LUU-2 Flare': 1, 'M117D bomb': 1, 'M117 bomb': 1, 'M118': 1, 'M129': 2, 'AN-M41A1': 1, 'M28 cluster bomb': 1, 'Mark 84 bomb': 1, 'MK 65': 1, 'BLU-54/B': 1, 'MK 82': 1, 'Mk 20': 1, 'MK 4': 1, 'MK 81': 1, 'MK 83': 1, 'Mk 84': 1, 'Bomb M122': 1, 'LAU-60/A': 1, 'Troops': 1, 'Unknown': 1, 'XM40E5 Gravel Bomb': 1})

# %% [markdown]
# Make the degree values a `dict`ionary, then add it as a network "attribute" with `networkx.set_node_attributes()`

# %%
degrees = dict(networkx.degree(G))
networkx.set_node_attributes(G, name='degree', values=degrees)

# %% [markdown]
# Make a Pandas dataframe from the degree data `G.nodes(data='degree')`, then sort from highest to lowest

# %%
degree_df = pd.DataFrame(G.nodes(data='degree'), columns=['node', 'degree'])
degree_df = degree_df.sort_values(by='degree', ascending=False)
degree_df
# Out:
#                    node  degree
# 1                  BOMB      77
# 30              MISSILE      13
# 18              SUPPORT      11
# 12               ROCKET      10
# 6                   NaN       5
# ..                  ...     ...
# 38        AIM-7 Sparrow       1
# 37         AIM-4 Falcon       1
# 36       AIM-26B Falcon       1
# 35      AGM-65 Maverick       1
# 110  XM40E5 Gravel Bomb       1
#
# [111 rows x 2 columns]

# %% [markdown]
# Plot the nodes with the highest degree values

# %%
num_nodes_to_inspect = 10
degree_df[:num_nodes_to_inspect].plot(x='node', y='degree', kind='barh').invert_yaxis()

# %% [markdown]
# ## Calculate Weighted Degree

# %% [markdown]
# Who has the most number of connections in the network (if you factor in edge weight)?

# %%
networkx.degree(G, weight='Weight')
# Out:
# DegreeView({'General Purpose Bomb': 1, 'BOMB': 77, 'Megaboller flash powder bomb': 1, 'An-M65': 1, 'Mark 83 bomb': 1, 'AN-M59': 1, nan: 5, 'AN-M30': 1, 'M47': 1, 'Howitzer ammo': 1, 'GUN': 2, 'Hydra 70': 1, 'ROCKET': 10, 'AN-M66': 1, 'Mk-84': 1, 'BLU-10/B': 1, 'AN-M57': 1, 'Mk 81': 1, 'SUPPORT': 11, 'BLU-34/B': 1, 'M-118': 1, 'BLU-11/B': 1, 'AN-M64': 1, 'Mk 82': 1, 'M-117': 1, 'BLU-1/B': 1, 'ADU-253/B': 2, 'ADU-272/B': 1, 'ADU-285/B': 1, 'AGM-12 Bullpup': 1, 'MISSILE': 13, 'AGM-45 Shrike': 1, 'AGM-62ÊWalleye': 2, 'AGM-62ÊWalleye I': 1, 'AGM-62A WALLEYE II': 1, 'AGM-65 Maverick': 1, 'AIM-26B Falcon': 1, 'AIM-4 Falcon': 1, 'AIM-7 Sparrow': 1, 'AIM-9 Sidewinder': 1, 'BLU-23/B': 1, 'BLU-26/B': 1, 'BLU-27/B': 1, 'BLU-31/B': 1, 'BLU-32/B': 1, 'BLU-33/B': 1, 'BLU-42/B': 1, 'BLU-43/B': 1, 'BLU-52/B': 1, 'BLU-73/B': 1, 'BLU-82/B': 1, 'CBU-30/A': 1, 'CBU-42/A': 1, 'CBU-46/A': 1, 'CBU-1/A': 1, 'CBU-10/B': 1, 'CBU-11/A': 1, 'CBU-12/A': 1, 'CBU-14/A': 1, 'CBU-15/A': 1, 'CBU-18/A': 1, 'CBU-19/A': 1, 'CBU-2/A': 1, 'CBU-22/A': 1, 'CBU-23/B': 1, 'CBU-24/B': 1, 'CBU-25/A': 1, 'CBU-28/A': 1, 'CBU-29/B': 1, 'CBU-3/A': 1, 'CBU-33/A': 1, 'CBU-34/A': 1, 'CBU-38/A': 1, 'CBU-39/A': 1, 'CBU-40/A': 1, 'CBU-49/B': 1, 'CBU-52/B': 1, 'CBU-55/B': 1, 'CBU-58/B': 1, 'CBU-7/A': 1, 'AIM-26 Falcon': 1, 'BOLT-117': 1, 'LAU-10/A': 1, 'LAU-3/A': 1, 'LAU-32/A': 1, 'LAU-33/A': 1, 'LAU-56/A': 1, 'LAU-59/A': 1, 'LAU-68/A': 1, 'M104 Bomb': 1, 'LUU-2 Flare': 1, 'M117D bomb': 1, 'M117 bomb': 1, 'M118': 1, 'M129': 2, 'AN-M41A1': 1, 'M28 cluster bomb': 1, 'Mark 84 bomb': 1, 'MK 65': 1, 'BLU-54/B': 1, 'MK 82': 1, 'Mk 20': 1, 'MK 4': 1, 'MK 81': 1, 'MK 83': 1, 'Mk 84': 1, 'Bomb M122': 1, 'LAU-60/A': 1, 'Troops': 1, 'Unknown': 1, 'XM40E5 Gravel Bomb': 1})

# %% [markdown]
# Make the weighted degree values a `dict`ionary, then add it as a network "attribute" with `networkx.set_node_attributes()`

# %%
weighted_degrees = dict(networkx.degree(G, weight='Weight'))
networkx.set_node_attributes(G, name='weighted_degree', values=weighted_degrees)

# %% [markdown]
# Make a Pandas dataframe from the degree data `G.nodes(data='weighted_degree')`, then sort from highest to lowest

# %%
weighted_degree_df = pd.DataFrame(G.nodes(data='weighted_degree'), columns=['node', 'weighted_degree'])
weighted_degree_df = weighted_degree_df.sort_values(by='weighted_degree', ascending=False)
weighted_degree_df
# Out:
#                    node  weighted_degree
# 1                  BOMB               77
# 30              MISSILE               13
# 18              SUPPORT               11
# 12               ROCKET               10
# 6                   NaN                5
# ..                  ...              ...
# 38        AIM-7 Sparrow                1
# 37         AIM-4 Falcon                1
# 36       AIM-26B Falcon                1
# 35      AGM-65 Maverick                1
# 110  XM40E5 Gravel Bomb                1
#
# [111 rows x 2 columns]

# %% [markdown]
# Plot the nodes with the highest weighted degree values

# %%
num_nodes_to_inspect = 10
weighted_degree_df[:num_nodes_to_inspect].plot(x='node', y='weighted_degree', color='orange', kind='barh').invert_yaxis()

# %% [markdown]
# ## Calculate Betweenness Centrality Scores

# %% [markdown]
# Who connects the most other nodes in the network?

# %%
networkx.betweenness_centrality(G)
# Out:
# {'General Purpose Bomb': 0.0,
#  'BOMB': 0.8963719766472061,
#  'Megaboller flash powder bomb': 0.0,
#  'An-M65': 0.0,
#  'Mark 83 bomb': 0.0,
#  'AN-M59': 0.0,
#  nan: 0.34120100083402827,
#  'AN-M30': 0.0,
#  'M47': 0.0,
#  'Howitzer ammo': 0.0,
#  'GUN': 0.01818181818181818,
#  'Hydra 70': 0.0,
#  'ROCKET': 0.15763135946622187,
#  'AN-M66': 0.0,
#  'Mk-84': 0.0,
#  'BLU-10/B': 0.0,
#  'AN-M57': 0.0,
#  'Mk 81': 0.0,
#  'SUPPORT': 0.1443703085904921,
#  'BLU-34/B': 0.0,
#  'M-118': 0.0,
#  'BLU-11/B': 0.0,
#  'AN-M64': 0.0,
#  'Mk 82': 0.0,
#  'M-117': 0.0,
#  'BLU-1/B': 0.0,
#  'ADU-253/B': 0.03740617180984154,
#  'ADU-272/B': 0.0,
#  'ADU-285/B': 0.0,
#  'AGM-12 Bullpup': 0.0,
#  'MISSILE': 0.19228523769808173,
#  'AGM-45 Shrike': 0.0,
#  'AGM-62ÊWalleye': 0.07539616346955796,
#  'AGM-62ÊWalleye I': 0.0,
#  'AGM-62A WALLEYE II': 0.0,
#  'AGM-65 Maverick': 0.0,
#  'AIM-26B Falcon': 0.0,
#  'AIM-4 Falcon': 0.0,
#  'AIM-7 Sparrow': 0.0,
#  'AIM-9 Sidewinder': 0.0,
#  'BLU-23/B': 0.0,
#  'BLU-26/B': 0.0,
#  'BLU-27/B': 0.0,
#  'BLU-31/B': 0.0,
#  'BLU-32/B': 0.0,
#  'BLU-33/B': 0.0,
#  'BLU-42/B': 0.0,
#  'BLU-43/B': 0.0,
#  'BLU-52/B': 0.0,
#  'BLU-73/B': 0.0,
#  'BLU-82/B': 0.0,
#  'CBU-30/A': 0.0,
#  'CBU-42/A': 0.0,
#  'CBU-46/A': 0.0,
#  'CBU-1/A': 0.0,
#  'CBU-10/B': 0.0,
#  'CBU-11/A': 0.0,
#  'CBU-12/A': 0.0,
#  'CBU-14/A': 0.0,
#  'CBU-15/A': 0.0,
#  'CBU-18/A': 0.0,
#  'CBU-19/A': 0.0,
#  'CBU-2/A': 0.0,
#  'CBU-22/A': 0.0,
#  'CBU-23/B': 0.0,
#  'CBU-24/B': 0.0,
#  'CBU-25/A': 0.0,
#  'CBU-28/A': 0.0,
#  'CBU-29/B': 0.0,
#  'CBU-3/A': 0.0,
#  'CBU-33/A': 0.0,
#  'CBU-34/A': 0.0,
#  'CBU-38/A': 0.0,
#  'CBU-39/A': 0.0,
#  'CBU-40/A': 0.0,
#  'CBU-49/B': 0.0,
#  'CBU-52/B': 0.0,
#  'CBU-55/B': 0.0,
#  'CBU-58/B': 0.0,
#  'CBU-7/A': 0.0,
#  'AIM-26 Falcon': 0.0,
#  'BOLT-117': 0.0,
#  'LAU-10/A': 0.0,
#  'LAU-3/A': 0.0,
#  'LAU-32/A': 0.0,
#  'LAU-33/A': 0.0,
#  'LAU-56/A': 0.0,
#  'LAU-59/A': 0.0,
#  'LAU-68/A': 0.0,
#  'M104 Bomb': 0.0,
#  'LUU-2 Flare': 0.0,
#  'M117D bomb': 0.0,
#  'M117 bomb': 0.0,
#  'M118': 0.0,
#  'M129': 0.03740617180984154,
#  'AN-M41A1': 0.0,
#  'M28 cluster bomb': 0.0,
#  'Mark 84 bomb': 0.0,
#  'MK 65': 0.0,
#  'BLU-54/B': 0.0,
#  'MK 82': 0.0,
#  'Mk 20': 0.0,
#  'MK 4': 0.0,
#  'MK 81': 0.0,
#  'MK 83': 0.0,
#  'Mk 84': 0.0,
#  'Bomb M122': 0.0,
#  'LAU-60/A': 0.0,
#  'Troops': 0.0,
#  'Unknown': 0.0,
#  'XM40E5 Gravel Bomb': 0.0}

# %%
betweenness_centrality = networkx.betweenness_centrality(G)

# %% [markdown]
# Add `betweenness_centrality` (which is already a dictionary) as a network "attribute" with `networkx.set_node_attributes()`

# %%
networkx.set_node_attributes(G, name='betweenness', values=betweenness_centrality)

# %% [markdown]
# Make a Pandas dataframe from the betweenness data `G.nodes(data='betweenness')`, then sort from highest to lowest

# %%
betweenness_df = pd.DataFrame(G.nodes(data='betweenness'), columns=['node', 'betweenness'])
betweenness_df = betweenness_df.sort_values(by='betweenness', ascending=False)
betweenness_df
# Out:
#                    node  betweenness
# 1                  BOMB     0.896372
# 6                   NaN     0.341201
# 30              MISSILE     0.192285
# 12               ROCKET     0.157631
# 18              SUPPORT     0.144370
# ..                  ...          ...
# 38        AIM-7 Sparrow     0.000000
# 37         AIM-4 Falcon     0.000000
# 36       AIM-26B Falcon     0.000000
# 35      AGM-65 Maverick     0.000000
# 110  XM40E5 Gravel Bomb     0.000000
#
# [111 rows x 2 columns]

# %% [markdown]
# Plot the nodes with the highest betweenness centrality scores

# %%
num_nodes_to_inspect = 10
betweenness_df[:num_nodes_to_inspect].plot(x='node', y='betweenness', color='green', kind='barh').invert_yaxis()

# %% [markdown]
# ## Communities

# %% [markdown]
# Who forms distinct communities within this network?

# %%
from networkx.algorithms import community

# %% [markdown]
# Calculate communities with `community.greedy_modularity_communities()`

# %%
for u, v, data in G.edges(data=True):
    try:
        data['weight'] = float(data['weight'])  # Convert weight to float
    except (KeyError, ValueError):
        # Handle cases where 'weight' attribute is missing or not convertible
        data['weight'] = 1.0  # Default weight if not present or invalid

# Verify that weights are now floats
for u, v, data in G.edges(data=True):
    print(type(data['weight']))  # Check the type of 'weight'

communities = community.greedy_modularity_communities(G, weight='weight')
print(communities)
# Out:
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/networkx/utils/mapped_queue.py in __lt__(self, other)
#      46             try:
# ---> 47                 return self.element < other.element
#      48             except TypeError as err:
#
# TypeError: '<' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-36-1936028d32cd> in <cell line: 12>()
#      10     print(type(data['weight']))  # Check the type of 'weight'
#      11
# ---> 12 communities = community.greedy_modularity_communities(G, weight='weight')
#      13 print(communities)
#
# /usr/local/lib/python3.10/dist-packages/networkx/utils/decorators.py in argmap_greedy_modularity_communities_35(G, weight, resolution, cutoff, best_n, backend, **backend_kwargs)
#       1 import bz2
#       2 import collections
# ----> 3 import gzip
#       4 import inspect
#       5 import itertools
#
# /usr/local/lib/python3.10/dist-packages/networkx/utils/backends.py in __call__(self, backend, *args, **kwargs)
#     631         if not backends:
#     632             # Fast path if no backends are installed
# --> 633             return self.orig_func(*args, **kwargs)
#     634
#     635         # Use `backend_name` in this function instead of `backend`
#
# /usr/local/lib/python3.10/dist-packages/networkx/algorithms/community/modularity_max.py in greedy_modularity_communities(G, weight, resolution, cutoff, best_n)
#     331
#     332     # construct the first best community
# --> 333     communities = next(community_gen)
#     334
#     335     # continue merging communities until one of the breaking criteria is satisfied
#
# /usr/local/lib/python3.10/dist-packages/networkx/algorithms/community/modularity_max.py in _greedy_modularity_communities_generator(G, weight, resolution)
#     105     dq_heap = {u: MappedQueue({(u, v): -dq for v, dq in dq_dict[u].items()}) for u in G}
#     106     # H -> all_dq_heap holds a heap with the best items for each node
# --> 107     H = MappedQueue([dq_heap[n].heap[0] for n in G if len(dq_heap[n]) > 0])
#     108
#     109     # Initialize single-node communities
#
# /usr/local/lib/python3.10/dist-packages/networkx/utils/mapped_queue.py in __init__(self, data)
#     161             self.heap = list(data)
#     162         self.position = {}
# --> 163         self._heapify()
#     164
#     165     def _heapify(self):
#
# /usr/local/lib/python3.10/dist-packages/networkx/utils/mapped_queue.py in _heapify(self)
#     165     def _heapify(self):
#     166         """Restore heap invariant and recalculate map."""
# --> 167         heapq.heapify(self.heap)
#     168         self.position = {elt: pos for pos, elt in enumerate(self.heap)}
#     169         if len(self.heap) != len(self.position):
#
# /usr/local/lib/python3.10/dist-packages/networkx/utils/mapped_queue.py in __lt__(self, other)
#      47                 return self.element < other.element
#      48             except TypeError as err:
# ---> 49                 raise TypeError(
#      50                     "Consider using a tuple, with a priority value that can be compared."
#      51                 )
#
# TypeError: Consider using a tuple, with a priority value that can be compared.

# %%
communities
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-b305c0f9b44f> in <cell line: 1>()
# ----> 1 communities
#
# NameError: name 'communities' is not defined

# %% [markdown]
# Make a `dict`ionary by looping through the communities and, for each member of the community, adding their community number

# %%
# Create empty dictionary
modularity_class = {}
#Loop through each community in the network
for community_number, community in enumerate(communities):
    #For each member of the community, add their community number
    for name in community:
        modularity_class[name] = community_number

# %% [markdown]
# Add modularity class to the network as an attribute

# %%
networkx.set_node_attributes(G, modularity_class, 'modularity_class')

# %% [markdown]
# Make a Pandas dataframe from modularity class network data `G.nodes(data='modularity_class')`

# %%
communities_df = pd.DataFrame(G.nodes(data='modularity_class'), columns=['node', 'modularity_class'])
communities_df = communities_df.sort_values(by='modularity_class', ascending=False)

# %%
communities_df
# Out:
#        node  modularity_class
# 25   Thoros                 4
# 18   Gendry                 4
# 14    Beric                 4
# 13    Anguy                 4
# 28   Belwas                 3
# ..      ...               ...
# 56     Shae                 0
# 57    Varys                 0
# 78   Qyburn                 0
# 79    Renly                 0
# 106  Walton                 0
#
# [107 rows x 2 columns]

# %% [markdown]
# Inspect each community in the network

# %%
communities_df[communities_df['modularity_class'] == 4]
# Out:
#       node  modularity_class
# 25  Thoros                 4
# 18  Gendry                 4
# 14   Beric                 4
# 13   Anguy                 4

# %%
communities_df[communities_df['modularity_class'] == 3]
# Out:
#          node  modularity_class
# 28     Belwas                 3
# 94  Jon Arryn                 3
# 65      Jorah                 3
# 67  Missandei                 3
# 71       Worm                 3
# 70    Viserys                 3
# 29  Barristan                 3
# 30    Illyrio                 3
# 69    Rhaegar                 3
# 68    Rakharo                 3
# 64      Aegon                 3
# 63   Daenerys                 3
# 5      Robert                 3
# 62       Irri                 3
# 61      Drogo                 3
# 60     Daario                 3
# 66    Kraznys                 3

# %%
communities_df[communities_df['modularity_class'] == 2]
# Out:
#              node  modularity_class
# 36          Theon                 2
# 37        Brienne                 2
# 43         Edmure                 2
# 40         Lothar                 2
# 42        Catelyn                 2
# 44         Hoster                 2
# 45          Jeyne                 2
# 46           Lysa                 2
# 47          Petyr                 2
# 48           Robb                 2
# 49         Roslin                 2
# 50          Sansa                 2
# 35            Nan                 2
# 41         Walder                 2
# 33          Luwin                 2
# 17         Cersei                 2
# 102        Ramsay                 2
# 75         Eddard                 2
# 101       Rickard                 2
# 15           Bran                 2
# 16        Brynden                 2
# 12           Arya                 2
# 98   Robert Arryn                 2
# 22         Rickon                 2
# 23          Roose                 2
# 97      Marillion                 2

# %%
communities_df[communities_df['modularity_class'] == 1]
# Out:
#             node  modularity_class
# 73       Cressen                 1
# 72         Davos                 1
# 58       Craster                 1
# 74     Salladhor                 1
# 76       Eddison                 1
# 77         Gilly                 1
# 87    Melisandre                 1
# 86         Dalla                 1
# 81         Janos                 1
# 59          Karl                 1
# 0          Aemon                 1
# 88         Orell                 1
# 32         Jojen                 1
# 2        Samwell                 1
# 104      Shireen                 1
# 8        Alliser                 1
# 9          Mance                 1
# 21           Jon                 1
# 89        Qhorin                 1
# 31         Hodor                 1
# 82         Bowen                 1
# 34         Meera                 1
# 93       Ygritte                 1
# 51       Stannis                 1
# 92           Val                 1
# 1          Grenn                 1
# 91          Styr                 1
# 90   Rattleshirt                 1

# %%
communities_df[communities_df['modularity_class'] == 0]
# Out:
#          node  modularity_class
# 84   Margaery                 0
# 96     Olenna                 0
# 99    Ellaria                 0
# 100      Mace                 0
# 103   Chataya                 0
# 105     Doran                 0
# 85   Myrcella                 0
# 95     Lancel                 0
# 53       Ilyn                 0
# 83      Kevan                 0
# 26      Balon                 0
# 3       Aerys                 0
# 4       Jaime                 0
# 6      Tyrion                 0
# 7       Tywin                 0
# 10      Amory                 0
# 11     Oberyn                 0
# 19     Gregor                 0
# 20    Joffrey                 0
# 24     Sandor                 0
# 27      Loras                 0
# 80     Tommen                 0
# 38      Bronn                 0
# 39    Podrick                 0
# 52       Elia                 0
# 54      Meryn                 0
# 55    Pycelle                 0
# 56       Shae                 0
# 57      Varys                 0
# 78     Qyburn                 0
# 79      Renly                 0
# 106    Walton                 0

# %% [markdown]
# Plot a sample of 40 characters with their modularity class indicated by a star

# %%
import seaborn as sns

# %%
#Set figure size
plt.figure(figsize=(4,12))

#Plot a categorical scatter plot from the dataframe communities_df.sample(40)
ax =sns.stripplot(x='modularity_class', y='node', data=communities_df.sample(40),
              hue='modularity_class', marker='*',size=15)
#Set legend outside the plot with bbox_to_anchor
ax.legend(loc='upper right',bbox_to_anchor=(1.5, 1), title='Modularity Class')
ax.set_title("GOT Characters By Modularity Class\n(Random Sample)")
plt.show()

# %% [markdown]
# Plot all GOT characters with their modularity class indicated by a star (tak

# %%
plt.figure(figsize=(4,25))

ax =sns.stripplot(x='modularity_class', y='node', data=communities_df,
              hue='modularity_class', marker='*',size=15)

ax.legend(loc='upper right',bbox_to_anchor=(1.5, 1), title='Modularity Class')
ax.set_title("GOT Characters By Modularity Class")
plt.show()

# %%
plt.figure(figsize=(4,25))

ax =sns.stripplot(x='modularity_class', y='node', data=communities_df,
              hue='modularity_class', marker='*',size=15)

ax.legend(loc='upper right',bbox_to_anchor=(1.5, 1), title='Modularity Class')
ax.set_title("GOT Characters By Modularity Class")
plt.show()

# %% [markdown]
# ## All Network Metrics

# %% [markdown]
# Create a Pandas dataframe of all network attributes by creating a `dict`ionary of `G.nodes(data=True)`...

# %%
dict(G.nodes(data=True))
# Out:
# {'Aemon': {'degree': 5,
#   'weighted_degree': 74,
#   'betweenness': 0.004622508177397137,
#   'modularity_class': 1},
#  'Grenn': {'degree': 4,
#   'weighted_degree': 81,
#   'betweenness': 5.989817310572027e-05,
#   'modularity_class': 1},
#  'Samwell': {'degree': 15,
#   'weighted_degree': 282,
#   'betweenness': 0.03227262859511145,
#   'modularity_class': 1},
#  'Aerys': {'degree': 4,
#   'weighted_degree': 37,
#   'betweenness': 0.0,
#   'modularity_class': 0},
#  'Jaime': {'degree': 24,
#   'weighted_degree': 372,
#   'betweenness': 0.09994344156136246,
#   'modularity_class': 0},
#  'Robert': {'degree': 18,
#   'weighted_degree': 128,
#   'betweenness': 0.2094523840293194,
#   'modularity_class': 3},
#  'Tyrion': {'degree': 36,
#   'weighted_degree': 551,
#   'betweenness': 0.19791284320277353,
#   'modularity_class': 0},
#  'Tywin': {'degree': 22,
#   'weighted_degree': 204,
#   'betweenness': 0.06553840423231058,
#   'modularity_class': 0},
#  'Alliser': {'degree': 3,
#   'weighted_degree': 29,
#   'betweenness': 0.0,
#   'modularity_class': 1},
#  'Mance': {'degree': 12,
#   'weighted_degree': 160,
#   'betweenness': 0.007275961371756524,
#   'modularity_class': 1},
#  'Amory': {'degree': 1,
#   'weighted_degree': 5,
#   'betweenness': 0.0,
#   'modularity_class': 0},
#  'Oberyn': {'degree': 7,
#   'weighted_degree': 76,
#   'betweenness': 0.01958014232946847,
#   'modularity_class': 0},
#  'Arya': {'degree': 19,
#   'weighted_degree': 269,
#   'betweenness': 0.07960711308183888,
#   'modularity_class': 2},
#  'Anguy': {'degree': 2,
#   'weighted_degree': 15,
#   'betweenness': 0.0,
#   'modularity_class': 4},
#  'Beric': {'degree': 6,
#   'weighted_degree': 75,
#   'betweenness': 0.0006091214266627511,
#   'modularity_class': 4},
#  'Bran': {'degree': 14,
#   'weighted_degree': 344,
#   'betweenness': 0.06301659941786954,
#   'modularity_class': 2},
#  'Brynden': {'degree': 8,
#   'weighted_degree': 55,
#   'betweenness': 0.004727134574764742,
#   'modularity_class': 2},
#  'Cersei': {'degree': 20,
#   'weighted_degree': 226,
#   'betweenness': 0.02674643287824232,
#   'modularity_class': 2},
#  'Gendry': {'degree': 4,
#   'weighted_degree': 59,
#   'betweenness': 0.0,
#   'modularity_class': 4},
#  'Gregor': {'degree': 12,
#   'weighted_degree': 117,
#   'betweenness': 0.005879915417737236,
#   'modularity_class': 0},
#  'Joffrey': {'degree': 18,
#   'weighted_degree': 255,
#   'betweenness': 0.025434099443917696,
#   'modularity_class': 0},
#  'Jon': {'degree': 26,
#   'weighted_degree': 442,
#   'betweenness': 0.22996466368473173,
#   'modularity_class': 1},
#  'Rickon': {'degree': 6,
#   'weighted_degree': 81,
#   'betweenness': 0.0007626320968639029,
#   'modularity_class': 2},
#  'Roose': {'degree': 4,
#   'weighted_degree': 17,
#   'betweenness': 0.0002629599012559427,
#   'modularity_class': 2},
#  'Sandor': {'degree': 13,
#   'weighted_degree': 137,
#   'betweenness': 0.014162278987154626,
#   'modularity_class': 0},
#  'Thoros': {'degree': 5,
#   'weighted_degree': 60,
#   'betweenness': 0.0019261823273239152,
#   'modularity_class': 4},
#  'Balon': {'degree': 6,
#   'weighted_degree': 29,
#   'betweenness': 0.0006281164805527878,
#   'modularity_class': 0},
#  'Loras': {'degree': 9,
#   'weighted_degree': 76,
#   'betweenness': 0.003780752291533962,
#   'modularity_class': 0},
#  'Belwas': {'degree': 4,
#   'weighted_degree': 67,
#   'betweenness': 0.018867924528301886,
#   'modularity_class': 3},
#  'Barristan': {'degree': 6,
#   'weighted_degree': 63,
#   'betweenness': 0.04011407489067884,
#   'modularity_class': 3},
#  'Illyrio': {'degree': 1,
#   'weighted_degree': 10,
#   'betweenness': 0.0,
#   'modularity_class': 3},
#  'Hodor': {'degree': 4,
#   'weighted_degree': 177,
#   'betweenness': 0.0021937273446681065,
#   'modularity_class': 1},
#  'Jojen': {'degree': 4,
#   'weighted_degree': 125,
#   'betweenness': 0.0004064518889316733,
#   'modularity_class': 1},
#  'Luwin': {'degree': 2,
#   'weighted_degree': 8,
#   'betweenness': 0.0,
#   'modularity_class': 2},
#  'Meera': {'degree': 5,
#   'weighted_degree': 139,
#   'betweenness': 0.0019922569692430686,
#   'modularity_class': 1},
#  'Nan': {'degree': 2,
#   'weighted_degree': 18,
#   'betweenness': 0.0,
#   'modularity_class': 2},
#  'Theon': {'degree': 4,
#   'weighted_degree': 38,
#   'betweenness': 0.00047177590304274953,
#   'modularity_class': 2},
#  'Brienne': {'degree': 7,
#   'weighted_degree': 122,
#   'betweenness': 0.0015376001520469229,
#   'modularity_class': 2},
#  'Bronn': {'degree': 4,
#   'weighted_degree': 59,
#   'betweenness': 0.00010482180293501046,
#   'modularity_class': 0},
#  'Podrick': {'degree': 5,
#   'weighted_degree': 64,
#   'betweenness': 0.0008358985235471674,
#   'modularity_class': 0},
#  'Lothar': {'degree': 5,
#   'weighted_degree': 34,
#   'betweenness': 0.0006600525898733143,
#   'modularity_class': 2},
#  'Walder': {'degree': 8,
#   'weighted_degree': 87,
#   'betweenness': 0.0032731813973401044,
#   'modularity_class': 2},
#  'Catelyn': {'degree': 18,
#   'weighted_degree': 184,
#   'betweenness': 0.04890588265764755,
#   'modularity_class': 2},
#  'Edmure': {'degree': 8,
#   'weighted_degree': 98,
#   'betweenness': 0.0063172332740347534,
#   'modularity_class': 2},
#  'Hoster': {'degree': 3,
#   'weighted_degree': 24,
#   'betweenness': 0.0002426336765959408,
#   'modularity_class': 2},
#  'Jeyne': {'degree': 2,
#   'weighted_degree': 28,
#   'betweenness': 0.0,
#   'modularity_class': 2},
#  'Lysa': {'degree': 10,
#   'weighted_degree': 108,
#   'betweenness': 0.015215156305177053,
#   'modularity_class': 2},
#  'Petyr': {'degree': 7,
#   'weighted_degree': 89,
#   'betweenness': 0.0011502139845250673,
#   'modularity_class': 2},
#  'Robb': {'degree': 25,
#   'weighted_degree': 342,
#   'betweenness': 0.1269644713830151,
#   'modularity_class': 2},
#  'Roslin': {'degree': 4,
#   'weighted_degree': 32,
#   'betweenness': 6.751960581039384e-05,
#   'modularity_class': 2},
#  'Sansa': {'degree': 26,
#   'weighted_degree': 383,
#   'betweenness': 0.12672031668498004,
#   'modularity_class': 2},
#  'Stannis': {'degree': 14,
#   'weighted_degree': 146,
#   'betweenness': 0.1026998617273264,
#   'modularity_class': 1},
#  'Elia': {'degree': 5,
#   'weighted_degree': 29,
#   'betweenness': 0.002996853410630337,
#   'modularity_class': 0},
#  'Ilyn': {'degree': 6,
#   'weighted_degree': 32,
#   'betweenness': 0.0,
#   'modularity_class': 0},
#  'Meryn': {'degree': 7,
#   'weighted_degree': 47,
#   'betweenness': 0.00025900705642512993,
#   'modularity_class': 0},
#  'Pycelle': {'degree': 4,
#   'weighted_degree': 24,
#   'betweenness': 0.0,
#   'modularity_class': 0},
#  'Shae': {'degree': 5,
#   'weighted_degree': 45,
#   'betweenness': 0.0012523948930099663,
#   'modularity_class': 0},
#  'Varys': {'degree': 7,
#   'weighted_degree': 49,
#   'betweenness': 0.0009094137867722772,
#   'modularity_class': 0},
#  'Craster': {'degree': 5,
#   'weighted_degree': 75,
#   'betweenness': 0.018867924528301886,
#   'modularity_class': 1},
#  'Karl': {'degree': 1,
#   'weighted_degree': 6,
#   'betweenness': 0.0,
#   'modularity_class': 1},
#  'Daario': {'degree': 4,
#   'weighted_degree': 30,
#   'betweenness': 5.989817310572027e-05,
#   'modularity_class': 3},
#  'Drogo': {'degree': 4,
#   'weighted_degree': 35,
#   'betweenness': 5.989817310572027e-05,
#   'modularity_class': 3},
#  'Irri': {'degree': 4,
#   'weighted_degree': 33,
#   'betweenness': 0.00017969451931716083,
#   'modularity_class': 3},
#  'Daenerys': {'degree': 14,
#   'weighted_degree': 232,
#   'betweenness': 0.15720345212054956,
#   'modularity_class': 3},
#  'Aegon': {'degree': 1,
#   'weighted_degree': 8,
#   'betweenness': 0.0,
#   'modularity_class': 3},
#  'Jorah': {'degree': 6,
#   'weighted_degree': 89,
#   'betweenness': 0.002329891127259132,
#   'modularity_class': 3},
#  'Kraznys': {'degree': 1,
#   'weighted_degree': 10,
#   'betweenness': 0.0,
#   'modularity_class': 3},
#  'Missandei': {'degree': 2,
#   'weighted_degree': 30,
#   'betweenness': 0.0,
#   'modularity_class': 3},
#  'Rakharo': {'degree': 1,
#   'weighted_degree': 7,
#   'betweenness': 0.0,
#   'modularity_class': 3},
#  'Rhaegar': {'degree': 6,
#   'weighted_degree': 42,
#   'betweenness': 0.007312671807481101,
#   'modularity_class': 3},
#  'Viserys': {'degree': 3,
#   'weighted_degree': 19,
#   'betweenness': 0.015644391307527945,
#   'modularity_class': 3},
#  'Worm': {'degree': 1,
#   'weighted_degree': 14,
#   'betweenness': 0.0,
#   'modularity_class': 3},
#  'Davos': {'degree': 5,
#   'weighted_degree': 87,
#   'betweenness': 0.056064690026954175,
#   'modularity_class': 1},
#  'Cressen': {'degree': 1,
#   'weighted_degree': 4,
#   'betweenness': 0.0,
#   'modularity_class': 1},
#  'Salladhor': {'degree': 1,
#   'weighted_degree': 16,
#   'betweenness': 0.0,
#   'modularity_class': 1},
#  'Eddard': {'degree': 12,
#   'weighted_degree': 108,
#   'betweenness': 0.019341416465723616,
#   'modularity_class': 2},
#  'Eddison': {'degree': 3,
#   'weighted_degree': 24,
#   'betweenness': 0.0,
#   'modularity_class': 1},
#  'Gilly': {'degree': 4,
#   'weighted_degree': 69,
#   'betweenness': 0.0,
#   'modularity_class': 1},
#  'Qyburn': {'degree': 1,
#   'weighted_degree': 11,
#   'betweenness': 0.0,
#   'modularity_class': 0},
#  'Renly': {'degree': 8,
#   'weighted_degree': 55,
#   'betweenness': 0.004227926858198188,
#   'modularity_class': 0},
#  'Tommen': {'degree': 5,
#   'weighted_degree': 31,
#   'betweenness': 0.0006984420191967362,
#   'modularity_class': 0},
#  'Janos': {'degree': 6,
#   'weighted_degree': 37,
#   'betweenness': 0.02355861153253357,
#   'modularity_class': 1},
#  'Bowen': {'degree': 2,
#   'weighted_degree': 11,
#   'betweenness': 0.0,
#   'modularity_class': 1},
#  'Kevan': {'degree': 6,
#   'weighted_degree': 50,
#   'betweenness': 0.019219915043818533,
#   'modularity_class': 0},
#  'Margaery': {'degree': 7,
#   'weighted_degree': 96,
#   'betweenness': 0.0010973522354777933,
#   'modularity_class': 0},
#  'Myrcella': {'degree': 4,
#   'weighted_degree': 18,
#   'betweenness': 0.0006235971795124951,
#   'modularity_class': 0},
#  'Dalla': {'degree': 3,
#   'weighted_degree': 21,
#   'betweenness': 0.0,
#   'modularity_class': 1},
#  'Melisandre': {'degree': 4,
#   'weighted_degree': 62,
#   'betweenness': 0.00860866854841803,
#   'modularity_class': 1},
#  'Orell': {'degree': 1,
#   'weighted_degree': 6,
#   'betweenness': 0.0,
#   'modularity_class': 1},
#  'Qhorin': {'degree': 5,
#   'weighted_degree': 59,
#   'betweenness': 0.0002635519616651692,
#   'modularity_class': 1},
#  'Rattleshirt': {'degree': 4,
#   'weighted_degree': 44,
#   'betweenness': 0.0,
#   'modularity_class': 1},
#  'Styr': {'degree': 2,
#   'weighted_degree': 23,
#   'betweenness': 0.0,
#   'modularity_class': 1},
#  'Val': {'degree': 4,
#   'weighted_degree': 31,
#   'betweenness': 0.005898334987101542,
#   'modularity_class': 1},
#  'Ygritte': {'degree': 4,
#   'weighted_degree': 82,
#   'betweenness': 0.0,
#   'modularity_class': 1},
#  'Jon Arryn': {'degree': 2,
#   'weighted_degree': 11,
#   'betweenness': 0.0005764583325230229,
#   'modularity_class': 3},
#  'Lancel': {'degree': 1,
#   'weighted_degree': 7,
#   'betweenness': 0.0,
#   'modularity_class': 0},
#  'Olenna': {'degree': 2,
#   'weighted_degree': 12,
#   'betweenness': 0.0,
#   'modularity_class': 0},
#  'Marillion': {'degree': 3,
#   'weighted_degree': 23,
#   'betweenness': 0.0,
#   'modularity_class': 2},
#  'Robert Arryn': {'degree': 3,
#   'weighted_degree': 19,
#   'betweenness': 0.0,
#   'modularity_class': 2},
#  'Ellaria': {'degree': 2,
#   'weighted_degree': 10,
#   'betweenness': 0.0,
#   'modularity_class': 0},
#  'Mace': {'degree': 3,
#   'weighted_degree': 20,
#   'betweenness': 0.0,
#   'modularity_class': 0},
#  'Rickard': {'degree': 2,
#   'weighted_degree': 11,
#   'betweenness': 0.0,
#   'modularity_class': 2},
#  'Ramsay': {'degree': 1,
#   'weighted_degree': 4,
#   'betweenness': 0.0,
#   'modularity_class': 2},
#  'Chataya': {'degree': 2,
#   'weighted_degree': 9,
#   'betweenness': 0.0,
#   'modularity_class': 0},
#  'Shireen': {'degree': 1,
#   'weighted_degree': 5,
#   'betweenness': 0.0,
#   'modularity_class': 1},
#  'Doran': {'degree': 1,
#   'weighted_degree': 5,
#   'betweenness': 0.0,
#   'modularity_class': 0},
#  'Walton': {'degree': 1,
#   'weighted_degree': 10,
#   'betweenness': 0.0,
#   'modularity_class': 0}}

# %% [markdown]
# ...and then [transposing it](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.T.html) (flipping the columns and rows) with `.T`

# %%
nodes_df = pd.DataFrame(dict(G.nodes(data=True))).T
nodes_df
# Out:
#               degree  weighted_degree  betweenness  modularity_class
# Aemon            5.0             74.0     0.004623               1.0
# Grenn            4.0             81.0     0.000060               1.0
# Samwell         15.0            282.0     0.032273               1.0
# Aerys            4.0             37.0     0.000000               0.0
# Jaime           24.0            372.0     0.099943               0.0
# Robert          18.0            128.0     0.209452               3.0
# Tyrion          36.0            551.0     0.197913               0.0
# Tywin           22.0            204.0     0.065538               0.0
# Alliser          3.0             29.0     0.000000               1.0
# Mance           12.0            160.0     0.007276               1.0
# Amory            1.0              5.0     0.000000               0.0
# Oberyn           7.0             76.0     0.019580               0.0
# Arya            19.0            269.0     0.079607               2.0
# Anguy            2.0             15.0     0.000000               4.0
# Beric            6.0             75.0     0.000609               4.0
# Bran            14.0            344.0     0.063017               2.0
# Brynden          8.0             55.0     0.004727               2.0
# Cersei          20.0            226.0     0.026746               2.0
# Gendry           4.0             59.0     0.000000               4.0
# Gregor          12.0            117.0     0.005880               0.0
# Joffrey         18.0            255.0     0.025434               0.0
# Jon             26.0            442.0     0.229965               1.0
# Rickon           6.0             81.0     0.000763               2.0
# Roose            4.0             17.0     0.000263               2.0
# Sandor          13.0            137.0     0.014162               0.0
# Thoros           5.0             60.0     0.001926               4.0
# Balon            6.0             29.0     0.000628               0.0
# Loras            9.0             76.0     0.003781               0.0
# Belwas           4.0             67.0     0.018868               3.0
# Barristan        6.0             63.0     0.040114               3.0
# Illyrio          1.0             10.0     0.000000               3.0
# Hodor            4.0            177.0     0.002194               1.0
# Jojen            4.0            125.0     0.000406               1.0
# Luwin            2.0              8.0     0.000000               2.0
# Meera            5.0            139.0     0.001992               1.0
# Nan              2.0             18.0     0.000000               2.0
# Theon            4.0             38.0     0.000472               2.0
# Brienne          7.0            122.0     0.001538               2.0
# Bronn            4.0             59.0     0.000105               0.0
# Podrick          5.0             64.0     0.000836               0.0
# Lothar           5.0             34.0     0.000660               2.0
# Walder           8.0             87.0     0.003273               2.0
# Catelyn         18.0            184.0     0.048906               2.0
# Edmure           8.0             98.0     0.006317               2.0
# Hoster           3.0             24.0     0.000243               2.0
# Jeyne            2.0             28.0     0.000000               2.0
# Lysa            10.0            108.0     0.015215               2.0
# Petyr            7.0             89.0     0.001150               2.0
# Robb            25.0            342.0     0.126964               2.0
# Roslin           4.0             32.0     0.000068               2.0
# Sansa           26.0            383.0     0.126720               2.0
# Stannis         14.0            146.0     0.102700               1.0
# Elia             5.0             29.0     0.002997               0.0
# Ilyn             6.0             32.0     0.000000               0.0
# Meryn            7.0             47.0     0.000259               0.0
# Pycelle          4.0             24.0     0.000000               0.0
# Shae             5.0             45.0     0.001252               0.0
# Varys            7.0             49.0     0.000909               0.0
# Craster          5.0             75.0     0.018868               1.0
# Karl             1.0              6.0     0.000000               1.0
# Daario           4.0             30.0     0.000060               3.0
# Drogo            4.0             35.0     0.000060               3.0
# Irri             4.0             33.0     0.000180               3.0
# Daenerys        14.0            232.0     0.157203               3.0
# Aegon            1.0              8.0     0.000000               3.0
# Jorah            6.0             89.0     0.002330               3.0
# Kraznys          1.0             10.0     0.000000               3.0
# Missandei        2.0             30.0     0.000000               3.0
# Rakharo          1.0              7.0     0.000000               3.0
# Rhaegar          6.0             42.0     0.007313               3.0
# Viserys          3.0             19.0     0.015644               3.0
# Worm             1.0             14.0     0.000000               3.0
# Davos            5.0             87.0     0.056065               1.0
# Cressen          1.0              4.0     0.000000               1.0
# Salladhor        1.0             16.0     0.000000               1.0
# Eddard          12.0            108.0     0.019341               2.0
# Eddison          3.0             24.0     0.000000               1.0
# Gilly            4.0             69.0     0.000000               1.0
# Qyburn           1.0             11.0     0.000000               0.0
# Renly            8.0             55.0     0.004228               0.0
# Tommen           5.0             31.0     0.000698               0.0
# Janos            6.0             37.0     0.023559               1.0
# Bowen            2.0             11.0     0.000000               1.0
# Kevan            6.0             50.0     0.019220               0.0
# Margaery         7.0             96.0     0.001097               0.0
# Myrcella         4.0             18.0     0.000624               0.0
# Dalla            3.0             21.0     0.000000               1.0
# Melisandre       4.0             62.0     0.008609               1.0
# Orell            1.0              6.0     0.000000               1.0
# Qhorin           5.0             59.0     0.000264               1.0
# Rattleshirt      4.0             44.0     0.000000               1.0
# Styr             2.0             23.0     0.000000               1.0
# Val              4.0             31.0     0.005898               1.0
# Ygritte          4.0             82.0     0.000000               1.0
# Jon Arryn        2.0             11.0     0.000576               3.0
# Lancel           1.0              7.0     0.000000               0.0
# Olenna           2.0             12.0     0.000000               0.0
# Marillion        3.0             23.0     0.000000               2.0
# Robert Arryn     3.0             19.0     0.000000               2.0
# Ellaria          2.0             10.0     0.000000               0.0
# Mace             3.0             20.0     0.000000               0.0
# Rickard          2.0             11.0     0.000000               2.0
# Ramsay           1.0              4.0     0.000000               2.0
# Chataya          2.0              9.0     0.000000               0.0
# Shireen          1.0              5.0     0.000000               1.0
# Doran            1.0              5.0     0.000000               0.0
# Walton           1.0             10.0     0.000000               0.0

# %%
nodes_df.sort_values(by='betweenness', ascending=False)
# Out:
#               degree  weighted_degree  betweenness  modularity_class
# Jon             26.0            442.0     0.229965               1.0
# Robert          18.0            128.0     0.209452               3.0
# Tyrion          36.0            551.0     0.197913               0.0
# Daenerys        14.0            232.0     0.157203               3.0
# Robb            25.0            342.0     0.126964               2.0
# Sansa           26.0            383.0     0.126720               2.0
# Stannis         14.0            146.0     0.102700               1.0
# Jaime           24.0            372.0     0.099943               0.0
# Arya            19.0            269.0     0.079607               2.0
# Tywin           22.0            204.0     0.065538               0.0
# Bran            14.0            344.0     0.063017               2.0
# Davos            5.0             87.0     0.056065               1.0
# Catelyn         18.0            184.0     0.048906               2.0
# Barristan        6.0             63.0     0.040114               3.0
# Samwell         15.0            282.0     0.032273               1.0
# Cersei          20.0            226.0     0.026746               2.0
# Joffrey         18.0            255.0     0.025434               0.0
# Janos            6.0             37.0     0.023559               1.0
# Oberyn           7.0             76.0     0.019580               0.0
# Eddard          12.0            108.0     0.019341               2.0
# Kevan            6.0             50.0     0.019220               0.0
# Belwas           4.0             67.0     0.018868               3.0
# Craster          5.0             75.0     0.018868               1.0
# Viserys          3.0             19.0     0.015644               3.0
# Lysa            10.0            108.0     0.015215               2.0
# Sandor          13.0            137.0     0.014162               0.0
# Melisandre       4.0             62.0     0.008609               1.0
# Rhaegar          6.0             42.0     0.007313               3.0
# Mance           12.0            160.0     0.007276               1.0
# Edmure           8.0             98.0     0.006317               2.0
# Val              4.0             31.0     0.005898               1.0
# Gregor          12.0            117.0     0.005880               0.0
# Brynden          8.0             55.0     0.004727               2.0
# Aemon            5.0             74.0     0.004623               1.0
# Renly            8.0             55.0     0.004228               0.0
# Loras            9.0             76.0     0.003781               0.0
# Walder           8.0             87.0     0.003273               2.0
# Elia             5.0             29.0     0.002997               0.0
# Jorah            6.0             89.0     0.002330               3.0
# Hodor            4.0            177.0     0.002194               1.0
# Meera            5.0            139.0     0.001992               1.0
# Thoros           5.0             60.0     0.001926               4.0
# Brienne          7.0            122.0     0.001538               2.0
# Shae             5.0             45.0     0.001252               0.0
# Petyr            7.0             89.0     0.001150               2.0
# Margaery         7.0             96.0     0.001097               0.0
# Varys            7.0             49.0     0.000909               0.0
# Podrick          5.0             64.0     0.000836               0.0
# Rickon           6.0             81.0     0.000763               2.0
# Tommen           5.0             31.0     0.000698               0.0
# Lothar           5.0             34.0     0.000660               2.0
# Balon            6.0             29.0     0.000628               0.0
# Myrcella         4.0             18.0     0.000624               0.0
# Beric            6.0             75.0     0.000609               4.0
# Jon Arryn        2.0             11.0     0.000576               3.0
# Theon            4.0             38.0     0.000472               2.0
# Jojen            4.0            125.0     0.000406               1.0
# Qhorin           5.0             59.0     0.000264               1.0
# Roose            4.0             17.0     0.000263               2.0
# Meryn            7.0             47.0     0.000259               0.0
# Hoster           3.0             24.0     0.000243               2.0
# Irri             4.0             33.0     0.000180               3.0
# Bronn            4.0             59.0     0.000105               0.0
# Roslin           4.0             32.0     0.000068               2.0
# Daario           4.0             30.0     0.000060               3.0
# Drogo            4.0             35.0     0.000060               3.0
# Grenn            4.0             81.0     0.000060               1.0
# Marillion        3.0             23.0     0.000000               2.0
# Ramsay           1.0              4.0     0.000000               2.0
# Doran            1.0              5.0     0.000000               0.0
# Mace             3.0             20.0     0.000000               0.0
# Shireen          1.0              5.0     0.000000               1.0
# Robert Arryn     3.0             19.0     0.000000               2.0
# Dalla            3.0             21.0     0.000000               1.0
# Chataya          2.0              9.0     0.000000               0.0
# Orell            1.0              6.0     0.000000               1.0
# Ygritte          4.0             82.0     0.000000               1.0
# Olenna           2.0             12.0     0.000000               0.0
# Rattleshirt      4.0             44.0     0.000000               1.0
# Rickard          2.0             11.0     0.000000               2.0
# Lancel           1.0              7.0     0.000000               0.0
# Styr             2.0             23.0     0.000000               1.0
# Ellaria          2.0             10.0     0.000000               0.0
# Ilyn             6.0             32.0     0.000000               0.0
# Bowen            2.0             11.0     0.000000               1.0
# Pycelle          4.0             24.0     0.000000               0.0
# Aerys            4.0             37.0     0.000000               0.0
# Alliser          3.0             29.0     0.000000               1.0
# Amory            1.0              5.0     0.000000               0.0
# Anguy            2.0             15.0     0.000000               4.0
# Gendry           4.0             59.0     0.000000               4.0
# Illyrio          1.0             10.0     0.000000               3.0
# Luwin            2.0              8.0     0.000000               2.0
# Nan              2.0             18.0     0.000000               2.0
# Jeyne            2.0             28.0     0.000000               2.0
# Karl             1.0              6.0     0.000000               1.0
# Qyburn           1.0             11.0     0.000000               0.0
# Aegon            1.0              8.0     0.000000               3.0
# Kraznys          1.0             10.0     0.000000               3.0
# Missandei        2.0             30.0     0.000000               3.0
# Rakharo          1.0              7.0     0.000000               3.0
# Worm             1.0             14.0     0.000000               3.0
# Cressen          1.0              4.0     0.000000               1.0
# Salladhor        1.0             16.0     0.000000               1.0
# Eddison          3.0             24.0     0.000000               1.0
# Gilly            4.0             69.0     0.000000               1.0
# Walton           1.0             10.0     0.000000               0.0
